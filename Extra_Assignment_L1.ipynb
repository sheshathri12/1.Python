# %%
print("Hope Ai")
# Out:
# Hope Ai

# %%
institute_name=input("Enter the Institute Name:")
# Out:
# Enter the Institute Name: Hope Ai

# %%
name=input("Enter the Name:")
Age=int(input("Enter the Age:"))
school_name=input("Enter the School Name:")
degree=input("Enter the degree:")
# Out:
# Enter the Name: Sheshathri
# Enter the Age: 30
# Enter the School Name: Apec
# Enter the degree: B.Tech(IT)

# %%
a=int(input("a="))
b=int(input("b="))
c=a+b
print("add=",c)
# Out:
# a= 10
# b= 20
# add= 30

# %%
a=int(input("a="))
b=int(input("b="))
c=a-b
print("sub=",c)
# Out:
# a= 30
# b= 20
# sub= 10

# %%
a=int(input("a="))
b=int(input("b="))
c=a*b
print("Mul=",c)
# Out:
# a= 20
# b= 40
# Mul= 800

# %%
a=int(input("a="))
b=int(input("b="))
c=a/b
print("Div=",c)
# Out:
# a= 20
# b= 5
# Div= 4.0

# %%
a=int(input("a="))
b=int(input("b="))
c=a%b
print("Modulo=",c)
# Out:
# a= 76
# b= 31
# Modulo= 14

# %%
a=int(input("a="))
b=int(input("b="))
c=a**b
print("pow=",c)
# Out:
# a= 4
# b= 4
# pow= 256
